# %% [markdown]
# # Embedding a tutorial video
#
# - Use the rich IPython output to directly embed the video in a live notebook
# - Provide a link to youtube so that static notebooks (e.g. on github) remain accessible

# %%
#@title Video: Intro
from IPython.display import YouTubeVideo
video = YouTubeVideo(id='wbZ60vdnoqw', width=854, height=480, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video
# Out:
# Video available at https://youtube.com/watch?v=wbZ60vdnoqw
