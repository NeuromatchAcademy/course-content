# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuromatchAcademy/course-content/blob/neuro-vids/tutorials/W0D0_NeuroVideoSeries/student/W0D0_Tutorial6.ipynb" target="_blank"><img alt="Open In Colab" src="https://colab.research.google.com/assets/colab-badge.svg"/></a>

# %% [markdown]
# # Brain Signals: LFP
# **Neuro Video Series**
#
# **By Neuromatch Academy**
#
# **Content creator**: Gaute Einevoll
#
# **Content reviewers**: Richard Gao, Jiaxin Tu, Tara van Viegen, Sirisha Sripada
#
# **Video editors, captioners, and translators**: Manisha Sinha, Tara van Viegen, Shuze Liu

# %% [markdown]
# ## Video

# %%
# @markdown
from ipywidgets import widgets

out2 = widgets.Output()
with out2:
  from IPython.display import IFrame
  class BiliVideo(IFrame):
      def __init__(self, id, page=1, width=400, height=300, **kwargs):
          self.id=id
          src = "https://player.bilibili.com/player.html?bvid={0}&page={1}".format(id, page)
          super(BiliVideo, self).__init__(src, width, height, **kwargs)

  video = BiliVideo(id="BV17o4y1C7K4", width=730, height=410, fs=1)
  print("Video available at https://www.bilibili.com/video/{0}".format(video.id))
  display(video)

out1 = widgets.Output()
with out1:
  from IPython.display import YouTubeVideo
  video = YouTubeVideo(id="PwkYgrTE2fU", width=730, height=410, fs=1, rel=0)
  print("Video available at https://youtube.com/watch?v=" + video.id)
  display(video)

out = widgets.Tab([out1, out2])
out.set_title(0, 'Youtube')
out.set_title(1, 'Bilibili')

display(out)

# %% [markdown]
# ## Slides

# %%
# @markdown
from IPython.display import IFrame
out = widgets.Output()
with out:
    display(IFrame(src=f"https://mfr.ca-1.osf.io/render?url=https://osf.io/w9tgp/?direct%26mode=render%26action=download%26mode=rende", width=730, height=410))
display(out)
